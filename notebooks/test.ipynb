# %%
from ultralytics import YOLO
model = YOLO('../assets/weights/ball_player_yolo26x.pt')

# %%
results = model.predict('../assets/samples/test1.mp4', save=True)
print(results[0])
print('=======================')
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/416) /Users/dreaner/Dev/Tactix/notebooks/../assets/samples/test1.mp4: 384x640 23 players, 389.6ms
# video 1/1 (frame 2/416) /Users/dreaner/Dev/Tactix/notebooks/../assets/samples/test1.mp4: 384x640 2 balls, 23 players, 246.0ms
# video 1/1 (frame 3/416) /Users/dreaner/Dev/Tactix/notebooks/../assets/samples/test1.mp4: 384x640 2 balls, 23 players, 233.4ms
# ...
